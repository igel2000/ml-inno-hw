# %% [markdown]
# # Обработка выбросов в числовых столбцах

# %%
import warnings
warnings.filterwarnings('ignore')
from pprint import pprint, pformat
from pathlib import Path

import joblib

from my_lib import *
from my_config import *

# %%
dataset_df = joblib.load(Path(result_foler, dataset_filename_after_PrepareTarget))
params = joblib.load(Path(result_foler, params_filename_after_PrepareTarget))

# %%
show_boxes_plt(dataset_df, params["num_columns"])

# %% [markdown]
# Выбросы только в столбце `Annual Income`, но, судя по количеству и близости значений друг к другу - это скорее нормальные данные, чем выбросы. Оставим их.
