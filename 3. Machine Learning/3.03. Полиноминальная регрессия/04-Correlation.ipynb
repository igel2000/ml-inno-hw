# %% [markdown]
# # Корреляция

# %%
import warnings
warnings.filterwarnings('ignore')
from pprint import pprint, pformat
from pathlib import Path

import joblib

from my_lib import *
from my_config import *

# %%
dataset_df_catencoder = joblib.load(Path(result_foler, dataset_filename_after_CatEncoder))
params = joblib.load(Path(result_foler, params_filename_after_CatEncoder))

# %%
fig = px.imshow(dataset_df_catencoder[params["columns_X"]].corr(), height=1000, width=1000, text_auto='.2f')
fig.show()

# %% [markdown]
# Каких-то значимых корреляций нет.
